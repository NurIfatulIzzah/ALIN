# %% [markdown]
# ## Aljabar matrik
# #tidak mengerjakan tidak oleh masuk kelas
# - Berikan penjelasan tentang apa itu matrik
# - operasi matrik
# - penjumlahan perkalian, pengurangan, tranpose matrix
# - buat program untuk mengalihkan matrik A dan B

# %%
# Matrix
A = np.array([[1,3,9],[3,-2,6],[9,4,1]]) # matrix 3x3
B = np.array([[1,7,5],[2,4,5]]) # matrix 2x3
C = np.array([[3,2],[-1,2],[3,5]]) # matrix 3x2

# %%
A=np.array([[1,0],[0,1]])
print('A=',A)
